# %%
import numpy as np
import pylab as pl
from biosppy import storage

import pandas as pd

#chunk = pd.read_csv(r"C:\Users\정성엽\Desktop\Korea_Clinical_Datathone_2019\training\00001.csv",chunksize=1024)
chunk = pd.read_csv(r"C:\Users\정성엽\Downloads\Datathon 2019\data\training\03006.e.csv")
print("a")
# Out:
# a

# %%
sample = chunk

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sample['ART'][:1000])

# %%
sample_ECG = sample['ECG_II'][:5000]

# %%
sample_ECG = np.array(sample_ECG)

# %%
plt.plot(sample_ECG)

# %%
from biosppy.signals import ecg

# %%
fig = plt.figure(figsize=(12,6))
outputs = ecg.ecg(signal=sample_ECG,sampling_rate=500)

# %%
output0 = outputs[0]
output1 = outputs[1]
output2 = outputs[2]
output3 = outputs[3]
output4 = outputs[4]
output5 = outputs[5]
output6 = outputs[6]

# %%
plt.plot(output1)

# %%
from torch import nn
from torch.nn import functional as F
